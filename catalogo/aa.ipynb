# %%
import pandas as pd


df = pd.read_excel('catalogoCompletoINEGI.xlsx')

df
# Out:
#                                                 Variables  Claves  \
# 0       Indicadores económicos de coyuntura > Població...  289242
# 1       Indicadores económicos de coyuntura > Població...  289243
# 2       Indicadores económicos de coyuntura > Població...  289244
# 3       Indicadores económicos de coyuntura > Població...  289245
# 4       Indicadores económicos de coyuntura > Població...  289246
# ...                                                   ...     ...
# 250432  Indicadores económicos de coyuntura > Balanza ...     922
# 250433  Indicadores económicos de coyuntura > Balanza ...     923
# 250434  Indicadores económicos de coyuntura > Balanza ...     924
# 250435  Indicadores económicos de coyuntura > Índices ...  910392
# 250436  Indicadores económicos de coyuntura > Índices ...  910399
#
#                                FechaActualizacion  \
# 0       Fecha de última actualización: 2023-11-27
# 1       Fecha de última actualización: 2023-11-27
# ...

# %%
df.to_pickle('catalogoINEGI.pkl')

# %%
import pickle
import pandas as pd

def load_data_objeto(url):
    with open(url, 'rb') as f:
        # Cargar el objeto desde el archivo
        catalogo_inegi = pickle.load(f)
    return catalogo_inegi

# %%
datos = load_data_objeto('catalogoINEGI.pkl')
datos
# Out:
#                                                 Variables  Claves  \
# 0       Indicadores económicos de coyuntura > Població...  289242
# 1       Indicadores económicos de coyuntura > Població...  289243
# 2       Indicadores económicos de coyuntura > Població...  289244
# 3       Indicadores económicos de coyuntura > Població...  289245
# 4       Indicadores económicos de coyuntura > Població...  289246
# ...                                                   ...     ...
# 250432  Indicadores económicos de coyuntura > Balanza ...     922
# 250433  Indicadores económicos de coyuntura > Balanza ...     923
# 250434  Indicadores económicos de coyuntura > Balanza ...     924
# 250435  Indicadores económicos de coyuntura > Índices ...  910392
# 250436  Indicadores económicos de coyuntura > Índices ...  910399
#
#                                FechaActualizacion  \
# 0       Fecha de última actualización: 2023-11-27
# 1       Fecha de última actualización: 2023-11-27
# ...

# %%
datos[datos['Claves'] == 436139]
# Out:
#                                                 Variables  Claves  \
# 250427  Indicadores económicos de coyuntura > Sistema ...  436139
#
#                                FechaActualizacion  \
# 250427  Fecha de última actualización: 2024-12-13
#
#                                       Nivel1
# 250427  Indicadores económicos de coyuntura
